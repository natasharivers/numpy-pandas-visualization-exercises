# %%
import pandas as pd
import numpy as np
from pydataset import data

# %%
mpg = data('mpg')

# %%
#data('mpg', show_doc=True)

# %% [markdown]
# ### #1 Copy the code from the lesson to create a dataframe full of student grades.

# %%
students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# %%
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
student_grades_df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
student_grades_df
# Out:
#        name  math  english  reading
# 0     Sally    73       75       63
# 1      Jane    85       91       77
# 2     Suzie    80       90       62
# 3     Billy    84       70       92
# 4       Ada    97       97       82
# 5      John    79       67       75
# 6    Thomas    86       74       75
# 7     Marie    69       60       80
# 8    Albert    99       68       69
# 9   Richard    93       60       79
# 10    Isaac    63       76       76
# 11     Alan    69       87       94

# %%
type(student_grades_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 1.a Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
student_grades_df['passing_english'] = student_grades_df['english'] >= 70

# %%
student_grades_df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    73       75       63             True
# 1      Jane    85       91       77             True
# 2     Suzie    80       90       62             True
# 3     Billy    84       70       92             True
# 4       Ada    97       97       82             True
# 5      John    79       67       75            False
# 6    Thomas    86       74       75             True
# 7     Marie    69       60       80            False
# 8    Albert    99       68       69            False
# 9   Richard    93       60       79            False
# 10    Isaac    63       76       76             True
# 11     Alan    69       87       94             True

# %% [markdown]
# #### #1.b Sort the english grades by the passing_english column. How are duplicates handled?

# %%
 student_grades_df.sort_values(['passing_english', 'english'], ascending =(False, True))
    #duplictes: handled by index sorting
# Out:
#        name  math  english  reading  passing_english
# 3     Billy    84       70       92             True
# 6    Thomas    86       74       75             True
# 0     Sally    73       75       63             True
# 10    Isaac    63       76       76             True
# 11     Alan    69       87       94             True
# 2     Suzie    80       90       62             True
# 1      Jane    85       91       77             True
# 4       Ada    97       97       82             True
# 7     Marie    69       60       80            False
# 9   Richard    93       60       79            False
# 5      John    79       67       75            False
# 8    Albert    99       68       69            False

# %% [markdown]
# #### #1.c Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
student_grades_df.sort_values(['passing_english', 'name'], ascending =(True, True))
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    99       68       69            False
# 5      John    79       67       75            False
# 7     Marie    69       60       80            False
# 9   Richard    93       60       79            False
# 4       Ada    97       97       82             True
# 11     Alan    69       87       94             True
# 3     Billy    84       70       92             True
# 10    Isaac    63       76       76             True
# 1      Jane    85       91       77             True
# 0     Sally    73       75       63             True
# 2     Suzie    80       90       62             True
# 6    Thomas    86       74       75             True

# %% [markdown]
# #### #1.d Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
student_grades_df.sort_values(['passing_english', 'english'], ascending =(True, True))
# Out:
#        name  math  english  reading  passing_english
# 7     Marie    69       60       80            False
# 9   Richard    93       60       79            False
# 5      John    79       67       75            False
# 8    Albert    99       68       69            False
# 3     Billy    84       70       92             True
# 6    Thomas    86       74       75             True
# 0     Sally    73       75       63             True
# 10    Isaac    63       76       76             True
# 11     Alan    69       87       94             True
# 2     Suzie    80       90       62             True
# 1      Jane    85       91       77             True
# 4       Ada    97       97       82             True

# %% [markdown]
# #### #1.e Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
student_grades_df['overall_grade'] = (student_grades_df['english'] + student_grades_df['math'] + student_grades_df['reading']) / 3
student_grades_df
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    69       86       73             True      76.000000
# 1      Jane    92       73       72             True      79.000000
# 2     Suzie    93       92       97             True      94.000000
# 3     Billy    85       88       95             True      89.333333
# 4       Ada    79       76       61             True      72.000000
# 5      John    93       66       77            False      78.666667
# 6    Thomas    77       71       96             True      81.333333
# 7     Marie    75       91       91             True      85.666667
# 8    Albert    94       68       66            False      76.000000
# 9   Richard    79       93       83             True      85.000000
# 10    Isaac    67       70       80             True      72.333333
# 11     Alan    99       88       74             True      87.000000

# %% [markdown]
# ### #2 Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg_df = data('mpg')

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# #### #2.a. How many rows and columns are there?

# %%
mpg_df.shape
#rows- 234, columns- 11
# Out:
# (234, 11)

# %% [markdown]
# #### #2.b. What are the data types of each column?

# %%
mpg_df.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
#other ways to complete #2.b:
mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# #### #2.c. Summarize the dataframe with .info and .describe

# %%
mpg_df.describe()
#gives numeric data types
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# #### #2.d. Rename the cty column to city.

# %%
mpg_df=mpg_df.rename(columns={'cty':'city'})
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# #### #2.e Rename the hwy column to highway.

# %%
mpg_df = mpg_df.rename(columns={'hwy':'highway'})
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# #### #2.f Do any cars have better city mileage than highway mileage?

# %%
#if cty > hwy return True
(mpg_df['city'] > mpg_df['highway']).any()
# Out:
# False

# %% [markdown]
# #### #2.g Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg_df['mileage_difference'] = mpg_df['highway'] - mpg_df['city'] 
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# #### #2.h Which car (or cars) has the highest mileage difference?

# %%
mpg_df.sort_values(['mileage_difference'], ascending =(False))
# honda civic and volkswagen new beetle
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
#      highway fl       class  mileage_difference
# ...

# %% [markdown]
# #### #2. i Which compact class car has the lowest highway mileage? The best?

# %%
#the lowest mileage- volkswagen jetta
compact_low_mileage = mpg_df[mpg_df['class'] == 'compact']

# %%
compact_low_mileage.sort_values(['highway'], ascending =(True)).head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
#the best mileage- volkswagen jetta
compact_best_mileage = mpg_df[mpg_df['class'] == 'compact']
compact_best_mileage.sort_values(['highway'], ascending =(False)).head(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference
# 213  compact                  11

# %% [markdown]
# #### #2.j Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg_df['average_mileage'] = (mpg_df['highway'] + mpg_df['city']) /2 
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# #### #2.k Which dodge car has the best average mileage? The worst?

# %%
#best mileage
mpg_df[mpg_df['manufacturer'].str.contains('dodge')].sort_values(['average_mileage'], ascending =(False)).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#       class  milage_difference  average_milage  mileage_difference  \
# 38  minivan                  6            21.0                   6
#
#     average_mileage
# 38             21.0

# %%
#worst mileage
mpg[mpg['manufacturer'].str.contains('dodge')].sort_values(['average_mileage'], ascending =(True)).head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  milage_difference  average_milage  mileage_difference  \
# 70   12  e  pickup                  3            10.5                   3
#
#     average_mileage
# 70             10.5

# %%
#### #3 Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
Mammals_df = data('Mammals')
data('Mammals', show_doc=True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %% [markdown]
# #### #3.a How many rows and columns are there?

# %%
Mammals_df.shape
#rows - 107
#columns- 4
# Out:
# (107, 4)

# %% [markdown]
# #### #3.b What are the data types?

# %%
Mammals_df.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# #### #3.c Summarize the dataframe with .info and .describe

# %%
Mammals_df.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
Mammals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %% [markdown]
# #### #3.d What is the the weight of the fastest animal?

# %%
Mammals_df.sort_values(['speed'], ascending =(False)).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
#another way to do #3.d
Mammals_df.nlargest(1, 'speed', keep ='all')
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# #### #3.e What is the overal percentage of specials?

# %%
#how many out of 107 items are specials
#specials == true
Mammals['specials'].value_counts()
#10 out of 107 are specials
# Out:
# False    97
# True     10
# Name: specials, dtype: int64

# %%
percent_specials = (Mammals['specials'].value_counts())/ len(Mammals)
percent_specials
#9.3458% are specials
# Out:
# False    0.906542
# True     0.093458
# Name: specials, dtype: float64

# %%
#another way to do #3.e
len(Mammals_df[Mammals_df['specials']== True])
#gives the number of 'specials'
# Out:
# 10

# %% [markdown]
# #### #3.f How many animals are hoppers that are above the median speed? What percentage is this?

# %%
#first, find out how many are hoppers
Mammals['hoppers'].value_counts()
#11 out of 107 are hoppers
# Out:
# False    96
# True     11
# Name: hoppers, dtype: int64

# %%
#second, what is the median speed
Median = Mammals['speed'].median()
Median
# Out:
# 48.0

# %%
#can also find the median like this:
Mammals[['speed']].describe()
# Out:
#             speed
# count  107.000000
# mean    46.208411
# std     26.716778
# min      1.600000
# 25%     22.500000
# 50%     48.000000
# 75%     65.000000
# max    110.000000

# %%
Mammals_df.sort_values(['hoppers', 'speed' ], ascending =(False, False)).head(10)
# Out:
#      weight  speed  hoppers  specials
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 96    4.600   64.0     True     False
# 100   2.000   64.0     True     False
# 99    3.500   56.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False
# 85    0.035   32.0     True     False
# 82    0.056   21.0     True     False

# %%
Mammals_df[Mammals_df['hoppers'] == True].sort_values(by= 'speed', ascending =False)
# Out:
#      weight  speed  hoppers  specials
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 96    4.600   64.0     True     False
# 100   2.000   64.0     True     False
# 99    3.500   56.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False
# 85    0.035   32.0     True     False
# 82    0.056   21.0     True     False
# 86    0.035   14.0     True     False

# %%
Mammals_df["speed"] > Median
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10     False
# 11      True
# 12      True
# 13      True
# 14     False
# 15      True
# 16     False
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
# 30      True
# 31      True
# 32     False
# 33      True
# 34      True
# 35      True
# 36      True
# 37     False
# 38     False
# 39      True
# 40      True
# 41      True
# 42      True
# 43      True
# 44     False
# 45      True
# 46     False
# 47     False
# 48      True
# 49      True
# 50     False
# 51      True
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59     False
# 60     False
# 61      True
# 62      True
# 63      True
# 64      True
# 65     False
# 66     False
# ...
