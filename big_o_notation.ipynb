# %%
import matplotlib.pyplot as plt
import math as math
import numpy as np
import pandas as pd

# %% [markdown]
# #5

# %%
plt.figure(figsize = (10,8))

x= (range(1,4))
y1 = [1 for n in x]
y2 = [math.log(n) for n in x]
y3 = [n for n in x]
y4= [n * math.log(n) for n in x]
y5= [n**2 for n in x]
y6= [2**n for n in x]
y7= [math.factorial(n) for n in x]
y8= [n**n for n in x]


plt.plot(x,y1, color = 'orange', label= 'y1= $O(1)$')
plt.plot(x,y2, color = 'green', label= 'y2 = $O(log n)$')
plt.plot(x,y3, color = 'magenta', label= 'y3= $O(n)$')
plt.plot(x,y4, color= 'black', label= 'y4 = $O(n log n)$')
plt.plot(x,y5, color= 'blue', label= 'y5 = $O(n^2)$')
plt.plot(x,y6, color= 'red', label= 'y6 = $O(2^n)$')
plt.plot(x,y7, color= 'yellow', label= 'y7 = $O(n!)$')
plt.plot(x,y8, color= 'brown', label= 'y8 = $O(n^n)$')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.annotate('LaTex', xy= (1.5,10))

plt.legend()

plt.show()

# %%
#TEACHER EXAMPLE:

x= (range(1,20))
y1 = [1 for n in x]
y2 = [math.log(n) for n in x]
y3 = x
y4= [(n * math.log(n)) for n in x]
y5= [n**2 for n in x]
y6= [2**n for n in x]
y7= [math.factorial(n) for n in x]
y8= [n**n for n in x]

plt.figure(figsize = (16,8))

plt.plot(x,y1, color = 'cyan', label= 'y1= $O(1)$', alpha = .2)
plt.plot(x,y2, color = 'red', label= 'y2 = $O(log n)$', alpha = .3)
plt.plot(x,y3, color = 'b', label= 'y3= $O(n)$', alpha = .4)
plt.plot(x,y4, color= 'g', label= 'y4 = $O(n log n)$', alpha = .5)
plt.plot(x,y5, color= 'coral', label= 'y5 = $O(n^2)$', alpha = .6)
plt.plot(x,y6, color= 'olive', label= 'y6 = $O(2^n)$', alpha = .7)
plt.plot(x,y7, color= 'lime', label= 'y7 = $O(n!)$', alpha = .8)
plt.plot(x,y8, color= 'violet', label= 'y8 = $O(n^n)$', alpha = .9)

plt.title('Big O Notation', fontsize = 20)
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.annotate('LaTex', xy= (1.5,10))

plt.legend(loc = 'upper right', fontsize = 14)
plt.xlim(1, 11)
plt.ylim(0, 50)

plt.show()

# %% [markdown]
# #I SEPERATED ALL THE GRAPHS TO TRY AND UNDERSTAND IT BETTER AND FOR PRACTICE

# %%
#y1 = [0(n) +1 for n in x]
y2 = [math.log(n) for n in x]
y3 = [n for n in x]
y4= [n * math.log(n) for n in x]
y5= [n**2 for n in x]
y6= [2**n for n in x]
y7= [math.factorial(n) for n in x]
y8= [n**n for n in x]

# %%
#Y1 DOESNT WORK
#x= (range(1,20))
#y1 = [0(n) +1 for n in x]
#fig= plt.figure(figsize=(6,4))
#plt.plot(x, y1, color ='m', label = '$O(1)$')

# %%
import matplotlib.pyplot as plt

#y2 works independently
x= (range(1,20))
y2 = [math.log(n) for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y2, color ='m', label = '$O(log n)$')
plt.legend()

# %%
#y3 works independently
x= (range(1,20))
y3 = [n for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y3, color ='m', label = '$O(n)$')
plt.legend()

# %%
#y4 works independently
x= (range(1,20))
y4 = [n * math.log(n) for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y4, color ='red', label = '$O(n log n)$')
plt.legend()

# %%
#y5 works independently
x= (range(1,20))
y5 = [n**2 for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y5, color ='blue', label = '$O(n^2)$')
plt.legend()

# %%
#y6 works independently
x= (range(1,20))
y6 = [2**n for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y6, color ='green', label = '$O(2^n)$')
plt.legend()

# %%
#y7 works independently
x= (range(1,20))
y7 = [math.factorial(n) for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y7, color ='orange', label = '$O(n!)$')
plt.legend()

# %%
#y8 works independently
x= (range(1,20))
y8 = [n**n for n in x]
fig= plt.figure(figsize=(6,4))
plt.plot(x, y8, color ='black', label = '$O(n^n)$')
plt.legend()

# %%
#6 *BONUS: Write the code necessary to write your name on a chart. 
#Use box letters

# %%
#LETTER T
x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')

# %%
#LETTER A
x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3

plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')

# %%
#COMBINE T,A
#LETTER T
x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')

#LETTER A
x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3

plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')


plt.show()

# %%
#LETTER S
x6 = 5, 6, 7
y6 = 1, 1, 1
x7 = 7, 7, 7, 7
y7 = 1, 2, 3, 3.5
x8 = 5, 6, 7
y8 = 3.5, 3.5, 3.5
x9 =  5, 5, 5, 5
y9 =  3.5, 4, 5, 6
x10 = 5, 6, 7
y10 = 6, 6, 6

plt.plot(x6, y6, linewidth=5, color = 'purple')
plt.plot(x7, y7, linewidth=5, color = 'purple')
plt.plot(x8, y8, linewidth=5, color = 'purple')
plt.plot(x9, y9, linewidth=5, color = 'purple')
plt.plot(x10, y10, linewidth=5, color = 'purple')

# %%
#COMBINE T,A,S
#LETTER T
x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')

#LETTER A
x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3

plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')

#LETTER S
x6 = 5, 6, 7
y6 = 1, 1, 1
x7 = 7, 7, 7, 7
y7 = 1, 2, 3, 3.5
x8 = 5, 6, 7
y8 = 3.5, 3.5, 3.5
x9 =  5, 5, 5, 5
y9 =  3.5, 4, 5, 6
x10 = 5, 6, 7
y10 = 6, 6, 6

plt.plot(x6, y6, linewidth=5, color = 'purple')
plt.plot(x7, y7, linewidth=5, color = 'purple')
plt.plot(x8, y8, linewidth=5, color = 'purple')
plt.plot(x9, y9, linewidth=5, color = 'purple')
plt.plot(x10, y10, linewidth=5, color = 'purple')

plt.show()

# %%
#LETTER H
x11 = 8, 8, 8, 8, 8, 8
y11 = 1, 2, 3, 4 ,5, 6
x12 = 8, 9, 10
y12 = 3.5, 3.5, 3.5
x13 = 10, 10, 10, 10, 10, 10
y13 = 1, 2, 3, 4 ,5, 6

plt.plot(x11, y11, linewidth=5, color = 'purple')
plt.plot(x12, y12, linewidth=5, color = 'purple')
plt.plot(x13, y13, linewidth=5, color = 'purple')

# %%
#COMBINE T,A,S,H
#LETTER T
x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')

#LETTER A
x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3

plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')

#LETTER S
x6 = 5, 6, 7
y6 = 1, 1, 1
x7 = 7, 7, 7, 7
y7 = 1, 2, 3, 3.5
x8 = 5, 6, 7
y8 = 3.5, 3.5, 3.5
x9 =  5, 5, 5, 5
y9 =  3.5, 4, 5, 6
x10 = 5, 6, 7
y10 = 6, 6, 6

plt.plot(x6, y6, linewidth=5, color = 'purple')
plt.plot(x7, y7, linewidth=5, color = 'purple')
plt.plot(x8, y8, linewidth=5, color = 'purple')
plt.plot(x9, y9, linewidth=5, color = 'purple')
plt.plot(x10, y10, linewidth=5, color = 'purple')

x11 = 8, 8, 8, 8, 8, 8
y11 = 1, 2, 3, 4 ,5, 6
x12 = 8, 9, 10
y12 = 3.5, 3.5, 3.5
x13 = 10, 10, 10, 10, 10, 10
y13 = 1, 2, 3, 4 ,5, 6

plt.plot(x11, y11, linewidth=5, color = 'purple')
plt.plot(x12, y12, linewidth=5, color = 'purple')
plt.plot(x13, y13, linewidth=5, color = 'purple')

plt.show()

# %%
#LETTER A
x14 = 10, 11
y14 = 1, 6
x15 = 11, 12
y15 = 6, 1
x16 = 10.4, 11.6
y16 = 3, 3

plt.plot(x14, y14, linewidth=5, color = 'purple')
plt.plot(x15, y15, linewidth=5, color = 'purple')
plt.plot(x16, y16, linewidth=5, color = 'purple')

# %%
#COMPLETE

x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')


x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3

plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')


x6 = 5.25, 6, 7
y6 = 1, 1, 1
x7 = 7, 7, 7, 7
y7 = 1, 2, 3, 3.5
x8 = 5, 6, 7
y8 = 3.5, 3.5, 3.5
x9 =  5, 5, 5, 5
y9 =  3.5, 4, 5, 6
x10 = 5, 6, 7
y10 = 6, 6, 6

plt.plot(x6, y6, linewidth=5, color = 'purple')
plt.plot(x7, y7, linewidth=5, color = 'purple')
plt.plot(x8, y8, linewidth=5, color = 'purple')
plt.plot(x9, y9, linewidth=5, color = 'purple')
plt.plot(x10, y10, linewidth=5, color = 'purple')

x11 = 8, 8, 8, 8, 8, 8
y11 = 1, 2, 3, 4 ,5, 6
x12 = 8, 9, 10
y12 = 3.5, 3.5, 3.5
x13 = 10, 10, 10, 10, 10, 10
y13 = 1, 2, 3, 4 ,5, 6

plt.plot(x11, y11, linewidth=5, color = 'purple')
plt.plot(x12, y12, linewidth=5, color = 'purple')
plt.plot(x13, y13, linewidth=5, color = 'purple')


x14 = 10.25, 11
y14 = 1, 6
x15 = 11, 12
y15 = 6, 1
x16 = 10.5, 11.6
y16 = 3, 3

plt.plot(x14, y14, linewidth=5, color = 'purple')
plt.plot(x15, y15, linewidth=5, color = 'purple')
plt.plot(x16, y16, linewidth=5, color = 'purple')

plt.show()

# %%
#TASHA
x1 =  2, 2, 2, 2, 2, 2
y1 = 1, 2, 3, 4, 5, 6
x2 =  1, 2, 3
y2 = 6, 6, 6
x3 = 3, 4
y3 = 1, 6
x4 = 4, 5
y4 = 6, 1
x5 = 3.4, 4.6
y5 = 3, 3
x6 = 5.25, 6, 7
y6 = 1, 1, 1
x7 = 7, 7, 7, 7
y7 = 1, 2, 3, 3.5
x8 = 5, 6, 7
y8 = 3.5, 3.5, 3.5
x9 =  5, 5, 5, 5
y9 =  3.5, 4, 5, 6
x10 = 5, 6, 7
y10 = 6, 6, 6
x11 = 8, 8, 8, 8, 8, 8
y11 = 1, 2, 3, 4 ,5, 6
x12 = 8, 9, 10
y12 = 3.5, 3.5, 3.5
x13 = 10, 10, 10, 10, 10, 10
y13 = 1, 2, 3, 4 ,5, 6
x14 = 10.25, 11
y14 = 1, 6
x15 = 11, 12
y15 = 6, 1
x16 = 10.5, 11.6
y16 = 3, 3

plt.plot(x1, y1, linewidth=5, color = 'purple')
plt.plot(x2, y2, linewidth=5, color = 'purple')
plt.plot(x3, y3, linewidth=5, color = 'purple')
plt.plot(x4, y4, linewidth=5, color = 'purple')
plt.plot(x5, y5, linewidth=5, color = 'purple')
plt.plot(x6, y6, linewidth=5, color = 'purple')
plt.plot(x7, y7, linewidth=5, color = 'purple')
plt.plot(x8, y8, linewidth=5, color = 'purple')
plt.plot(x9, y9, linewidth=5, color = 'purple')
plt.plot(x10, y10, linewidth=5, color = 'purple')
plt.plot(x11, y11, linewidth=5, color = 'purple')
plt.plot(x12, y12, linewidth=5, color = 'purple')
plt.plot(x13, y13, linewidth=5, color = 'purple')
plt.plot(x14, y14, linewidth=5, color = 'purple')
plt.plot(x15, y15, linewidth=5, color = 'purple')
plt.plot(x16, y16, linewidth=5, color = 'purple')

plt.show()
